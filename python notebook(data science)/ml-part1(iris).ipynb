# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#df=sns.load_dataset('iris')

# %%
#df.head()

# %%
from sklearn.datasets import load_iris

# %%
iris=load_iris()

# %%
iris_df=pd.DataFrame(data=iris.data,columns=iris.feature_names)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
target_df=pd.DataFrame(data=iris.target,columns=['species'])

# %%
'''def converter(specie):
    if specie==0:
        return 'setosa'
    elif specie==1:
        return 'vesicolor'
    else:
        return 'virginica'
    
target_df['species']=target_df['species'].apply(converter)

iris_df=pd.concat([iris_df,target_df],axis=1)
   '''
# Out:
# "def converter(specie):\n    if specie==0:\n        return 'setosa'\n    elif specie==1:\n        return 'vesicolor'\n    else:\n        return 'virginica'\n    \ntarget_df['species']=target_df['species'].apply(converter)\n\niris_df=pd.concat([iris_df,target_df],axis=1)\n   "

# %%
target_df['species']=target_df['species'].map({0:'setosa',1:'vesicolor',2:'virginica'})

iris_df=pd.concat([iris_df,target_df],axis=1)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
target_df
# Out:
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 1 columns]

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.pairplot(iris_df,hue='species')

# %% [markdown]
# ### Predict sepal length

# %%
iris_df['species']=iris_df['species'].map({'setosa':0,'vesicolor':1,'virginica':2})
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0          0
# ...

# %%
X=iris_df.drop(labels='sepal length (cm)',axis=1)
Y=iris_df['sepal length (cm)']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.33,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
mod=model.predict(X_test)

# %%
mod
# Out:
# array([5.46114587, 5.07345452, 4.9347765 , 6.99564965, 6.54274665,
#        5.98101314, 5.68344523, 5.47200924, 5.87249006, 4.687635  ,
#        6.2935498 , 5.53302753, 4.90789461, 7.34015348, 6.17439086,
#        6.09386911, 6.00159206, 6.01550096, 4.73818534, 6.6970219 ,
#        5.49567769, 5.21721782, 6.03683228, 6.24318298, 6.09386911,
#        5.5452921 , 5.09735047, 5.85437218, 4.84437129, 4.10007944,
#        6.64781317, 5.60092772, 6.64459972, 5.7094508 , 6.47068148,
#        6.18614616, 6.42031467, 5.96401471, 5.88658249, 6.82494485,
#        5.10127233, 4.76091786, 4.97328977, 6.47501437, 6.19911914,
#        4.51050332, 6.78415406, 5.98213258, 4.83046239, 4.93319177])

# %%
b = pd.concat([X_test, Y_test], axis=1)
b.head()
# Out:
#      sepal width (cm)  petal length (cm)  petal width (cm)  species  \
# 33                4.2                1.4               0.2        0
# 16                3.9                1.3               0.4        0
# 43                3.5                1.6               0.6        0
# 129               3.0                5.8               1.6        2
# 50                3.2                4.7               1.4        1
#
#      sepal length (cm)
# 33                 5.5
# 16                 5.4
# 43                 5.0
# 129                7.2
# 50                 7.0

# %%
b['pred_sepal_length'] = mod

# %%
b.head()
# Out:
#      sepal width (cm)  petal length (cm)  petal width (cm)  species  \
# 33                4.2                1.4               0.2        0
# 16                3.9                1.3               0.4        0
# 43                3.5                1.6               0.6        0
# 129               3.0                5.8               1.6        2
# 50                3.2                4.7               1.4        1
#
#      sepal length (cm)  pred_sepal_length
# 33                 5.5           5.461146
# 16                 5.4           5.073455
# 43                 5.0           4.934776
# 129                7.2           6.995650
# 50                 7.0           6.542747

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
print('Mean Absolute Error:', mean_absolute_error(Y_test, mod))
print('Mean Squared Error:', mean_squared_error(Y_test, mod))
print('Mean Root Squared Error:', np.sqrt(mean_squared_error(Y_test, mod)))
# Out:
# Mean Absolute Error: 0.25955709755630363
# Mean Squared Error: 0.1017452956423896
# Mean Root Squared Error: 0.3189753840696639
